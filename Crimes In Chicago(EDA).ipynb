# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import seaborn as sns
import plotly.plotly as py
from plotly.graph_objs import *
import pygal

# %%
crimes3['Primary Type'].value_counts()
# Out:
# THEFT                                329460
# BATTERY                              263700
# CRIMINAL DAMAGE                      155455
# NARCOTICS                            135240
# ASSAULT                               91289
# OTHER OFFENSE                         87874
# BURGLARY                              83397
# DECEPTIVE PRACTICE                    75495
# MOTOR VEHICLE THEFT                   61138
# ROBBERY                               57313
# CRIMINAL TRESPASS                     36912
# WEAPONS VIOLATION                     17233
# PUBLIC PEACE VIOLATION                13122
# OFFENSE INVOLVING CHILDREN            11398
# PROSTITUTION                           7633
# CRIM SEXUAL ASSAULT                    6823
# INTERFERENCE WITH PUBLIC OFFICER       6195
# SEX OFFENSE                            4885
# HOMICIDE                               2649
# ARSON                                  2217
# GAMBLING                               2212
# LIQUOR LAW VIOLATION                   1953
# KIDNAPPING                             1099
# STALKING                                828
# INTIMIDATION                            662
# OBSCENITY                               187
# NON-CRIMINAL                             93
# CONCEALED CARRY LICENSE VIOLATION        90
# PUBLIC INDECENCY                         62
# NON - CRIMINAL                           38
# OTHER NARCOTIC VIOLATION                 30
# HUMAN TRAFFICKING                        28
# NON-CRIMINAL (SUBJECT SPECIFIED)          4
# Name: Primary Type, dtype: int64

# %%
crimes3['Ward'].nunique()
# Out:
# 50

# %%
line_chart = pygal.HorizontalBar()
line_chart.title = 'Primary Type'
line_chart.y_labels = crimes3['Primary Type']
line_chart.add('Primary Type', crimes3.groupby([crimes3['Primary Type']]).size().sort_values(ascending=True))
line_chart.render_to_file('chart.svg')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-3fc50b9a1dc8> in <module>()
#       3 line_chart.y_labels = crimes3['Primary Type']
#       4 line_chart.add('Primary Type', crimes3.groupby([crimes3['Primary Type']]).size().sort_values(ascending=True))
# ----> 5 line_chart.render_to_file('chart.svg')
#
# c:\program files (x86)\python36-32\lib\site-packages\pygal\graph\public.py in render_to_file(self, filename, **kwargs)
#     112         """Render the graph, and write it to filename"""
#     113         with io.open(filename, 'w', encoding='utf-8') as f:
# --> 114             f.write(self.render(is_unicode=True, **kwargs))
#     115
#     116     def render_to_png(self, filename=None, dpi=72, **kwargs):
#
# c:\program files (x86)\python36-32\lib\site-packages\pygal\graph\public.py in render(self, is_unicode, **kwargs)
#      50     def render(self, is_unicode=False, **kwargs):
#      51         """Render the graph, and return the svg string"""
# ---> 52         self.setup(**kwargs)
#      53         svg = self.svg.render(
#      54             is_unicode=is_unicode, pretty_print=self.pretty_print)
#
# c:\program files (x86)\python36-32\lib\site-packages\pygal\graph\base.py in setup(self, **kwargs)
#     215         if self._len < 3:
#     216             self.interpolate = None
# --> 217         self._draw()
#     218         self.svg.pre_render()
#     219
#
# c:\program files (x86)\python36-32\lib\site-packages\pygal\graph\graph.py in _draw(self)
#     925         self._compute_x_labels_major()
#     926         self._compute_y_labels()
# --> 927         self._compute_y_labels_major()
#     928         self._compute_secondary()
#     929         self._post_compute()
#
# c:\program files (x86)\python36-32\lib\site-packages\pygal\graph\graph.py in _compute_y_labels_major(self)
#     889             self._y_labels_major = list(map(self._adapt, self.y_labels_major))
#     890         elif self._y_labels:
# --> 891             self._y_labels_major = majorize(cut(self._y_labels, 1))
#     892         else:
#     893             self._y_labels_major = []
#
# c:\program files (x86)\python36-32\lib\site-packages\pygal\util.py in majorize(values)
#      56     major_values = [
#      57         value for value in values if value / step == round(value / step)]
# ---> 58     return [value for value in sorted_values if value in major_values]
#      59
#      60
#
# c:\program files (x86)\python36-32\lib\site-packages\pygal\util.py in <listcomp>(.0)
#      56     major_values = [
#      57         value for value in values if value / step == round(value / step)]
# ---> 58     return [value for value in sorted_values if value in major_values]
#      59
#      60
#
# KeyboardInterrupt:

# %%
crimes3.head(10).T
# Out:
#                                                   0  \
# Unnamed: 0                                        3
# ID                                         10508693
# Case Number                                HZ250496
# Date                            2016-05-03 23:40:00
# Block                            013XX S SAWYER AVE
# IUCR                                           0486
# Primary Type                                BATTERY
# Description                 DOMESTIC BATTERY SIMPLE
# Location Description                      APARTMENT
# Arrest                                         True
# Domestic                                       True
# Beat                                           1022
# District                                         10
# Ward                                             24
# Community Area                                   29
# FBI Code                                        08B
# X Coordinate                            1.15491e+06
# Y Coordinate                            1.89368e+06
# Year                                           2016
# Updated On                   05/10/2016 03:56:50 PM
# Latitude                                    41.8641
# Longitude                                  -87.7068
# Location              (41.864073157, -87.706818608)
# Month                                             5
#
#                                                  1  \
# Unnamed: 0                                      89
# ID                                        10508695
# Case Number                               HZ250409
# Date                           2016-05-03 21:40:00
# Block                           061XX S DREXEL AVE
# IUCR                                          0486
# Primary Type                               BATTERY
# Description                DOMESTIC BATTERY SIMPLE
# Location Description                     RESIDENCE
# Arrest                                       False
# Domestic                                      True
# Beat                                           313
# District                                         3
# Ward                                            20
# Community Area                                  42
# FBI Code                                       08B
# X Coordinate                           1.18307e+06
# Y Coordinate                           1.86433e+06
# Year                                          2016
# Updated On                  05/10/2016 03:56:50 PM
# Latitude                                   41.7829
# Longitude                                 -87.6044
# Location              (41.782921527, -87.60436317)
# Month                                            5
#
#                                                   2  \
# Unnamed: 0                                      197
# ID                                         10508697
# Case Number                                HZ250503
# Date                            2016-05-03 23:31:00
# Block                           053XX W CHICAGO AVE
# IUCR                                           0470
# Primary Type                 PUBLIC PEACE VIOLATION
# Description                        RECKLESS CONDUCT
# Location Description                         STREET
# Arrest                                        False
# Domestic                                      False
# Beat                                           1524
# District                                         15
# Ward                                             37
# Community Area                                   25
# FBI Code                                         24
# X Coordinate                            1.14079e+06
# Y Coordinate                            1.90482e+06
# Year                                           2016
# Updated On                   05/10/2016 03:56:50 PM
# Latitude                                    41.8949
# Longitude                                  -87.7584
# Location              (41.894908283, -87.758371958)
# Month                                             5
#
#                                                   3  \
# Unnamed: 0                                      673
# ID                                         10508698
# Case Number                                HZ250424
# Date                            2016-05-03 22:10:00
# Block                             049XX W FULTON ST
# IUCR                                           0460
# Primary Type                                BATTERY
# Description                                  SIMPLE
# Location Description                       SIDEWALK
# Arrest                                        False
# Domestic                                      False
# Beat                                           1532
# District                                         15
# Ward                                             28
# Community Area                                   25
# FBI Code                                        08B
# X Coordinate                            1.14322e+06
# Y Coordinate                            1.90148e+06
# Year                                           2016
# Updated On                   05/10/2016 03:56:50 PM
# Latitude                                    41.8857
# Longitude                                  -87.7495
# Location              (41.885686845, -87.749515983)
# Month                                             5
#
#                                                   4  \
# Unnamed: 0                                      911
# ID                                         10508699
# Case Number                                HZ250455
# Date                            2016-05-03 22:00:00
# Block                             003XX N LOTUS AVE
# IUCR                                           0820
# Primary Type                                  THEFT
# Description                          $500 AND UNDER
# Location Description                      RESIDENCE
# Arrest                                        False
# Domestic                                       True
# Beat                                           1523
# District                                         15
# Ward                                             28
# Community Area                                   25
# FBI Code                                         06
# X Coordinate                            1.13989e+06
# Y Coordinate                            1.90168e+06
# Year                                           2016
# Updated On                   05/10/2016 03:56:50 PM
# Latitude                                    41.8863
# Longitude                                  -87.7618
# Location              (41.886297242, -87.761750709)
# Month                                             5
#
#                                                   5  \
# Unnamed: 0                                     1108
# ID                                         10508702
# Case Number                                HZ250447
# Date                            2016-05-03 22:35:00
# Block                          082XX S MARYLAND AVE
# IUCR                                           041A
# Primary Type                                BATTERY
# Description                     AGGRAVATED: HANDGUN
# Location Description                         STREET
# Arrest                                        False
# Domestic                                      False
# Beat                                            631
# District                                          6
# Ward                                              8
# Community Area                                   44
# FBI Code                                        04B
# X Coordinate                            1.18334e+06
# Y Coordinate                            1.85064e+06
# Year                                           2016
# Updated On                   05/10/2016 03:56:50 PM
# Latitude                                    41.7454
# Longitude                                  -87.6038
# Location              (41.745354023, -87.603798903)
# Month                                             5
#
#                                                    6  \
# Unnamed: 0                                      1130
# ID                                          10508703
# Case Number                                 HZ250489
# Date                             2016-05-03 22:30:00
# Block                               027XX S STATE ST
# IUCR                                            0460
# Primary Type                                 BATTERY
# Description                                   SIMPLE
# Location Description  CHA HALLWAY/STAIRWELL/ELEVATOR
# Arrest                                         False
# Domestic                                       False
# Beat                                             133
# District                                           1
# Ward                                               3
# Community Area                                    35
# FBI Code                                         08B
# X Coordinate                             1.17673e+06
# Y Coordinate                             1.88654e+06
# Year                                            2016
# Updated On                    05/10/2016 03:56:50 PM
# Latitude                                      41.844
# Longitude                                   -87.6269
# Location               (41.844023772, -87.626923253)
# Month                                              5
#
#                                                  7  \
# Unnamed: 0                                    1801
# ID                                        10508704
# Case Number                               HZ250514
# Date                           2016-05-03 21:30:00
# Block                              002XX E 46TH ST
# IUCR                                          0460
# Primary Type                               BATTERY
# Description                                 SIMPLE
# Location Description       RESIDENCE PORCH/HALLWAY
# Arrest                                       False
# Domestic                                     False
# Beat                                           215
# District                                         2
# Ward                                             3
# Community Area                                  38
# FBI Code                                       08B
# X Coordinate                           1.17851e+06
# Y Coordinate                           1.87457e+06
# Year                                          2016
# Updated On                  05/10/2016 03:56:50 PM
# Latitude                                   41.8111
# Longitude                                 -87.6207
# Location              (41.811133958, -87.62074077)
# Month                                            5
#
#                                                  8  \
# Unnamed: 0                                    1868
# ID                                        10508709
# Case Number                               HZ250523
# Date                           2016-05-03 16:00:00
# Block                            014XX W DEVON AVE
# IUCR                                          0460
# Primary Type                               BATTERY
# Description                                 SIMPLE
# Location Description                      SIDEWALK
# Arrest                                       False
# Domestic                                     False
# Beat                                          2432
# District                                        24
# Ward                                            40
# Community Area                                   1
# FBI Code                                       08B
# X Coordinate                            1.1657e+06
# Y Coordinate                           1.94262e+06
# Year                                          2016
# Updated On                  05/10/2016 03:56:50 PM
# Latitude                                   41.9981
# Longitude                                 -87.6658
# Location              (41.99813061, -87.665814038)
# Month                                            5
#
#                                                   9
# Unnamed: 0                                     1891
# ID                                         10508982
# Case Number                                HZ250667
# Date                            2016-05-03 22:30:00
# Block                           069XX S ASHLAND AVE
# IUCR                                           0486
# Primary Type                                BATTERY
# Description                 DOMESTIC BATTERY SIMPLE
# Location Description                         STREET
# Arrest                                        False
# Domestic                                       True
# Beat                                            735
# District                                          7
# Ward                                             17
# Community Area                                   67
# FBI Code                                        08B
# X Coordinate                            1.16688e+06
# Y Coordinate                             1.8588e+06
# Year                                           2016
# Updated On                   05/10/2016 03:56:50 PM
# Latitude                                    41.7681
# Longitude                                  -87.6639
# Location              (41.768096835, -87.663878589)
# Month                                             5

# %%
crimes_corr = crimes3.corr()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-50-61a21a1bad56> in <module>()
# ----> 1 crimes_corr = crimes3.corr()
#
# c:\program files (x86)\python36-32\lib\site-packages\pandas\core\frame.py in corr(self, method, min_periods)
#    5488
#    5489         if method == 'pearson':
# -> 5490             correl = libalgos.nancorr(_ensure_float64(mat), minp=min_periods)
#    5491         elif method == 'spearman':
#    5492             correl = libalgos.nancorr_spearman(_ensure_float64(mat),
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# MemoryError:

# %%
# !pip3 install plotly
# Out:
# Collecting plotly
#   Downloading https://files.pythonhosted.org/packages/a7/3d/4dcdbafc9d5c01f468d41999cd9ab733f38e9ea4e4bea5a62841fedf5f0e/plotly-2.5.1.tar.gz (24.9MB)
# Requirement already satisfied: decorator>=4.0.6 in c:\users\dell\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: nbformat>=4.2 in c:\users\dell\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: pytz in c:\users\dell\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\lib\site-packages (from plotly)
# Requirement already satisfied: six in c:\users\dell\anaconda3\lib\site-packages (from plotly)
# Building wheels for collected packages: plotly
#   Running setup.py bdist_wheel for plotly: started
#   Running setup.py bdist_wheel for plotly: finished with status 'done'
#   Stored in directory: C:\Users\dell\AppData\Local\pip\Cache\wheels\33\be\39\f82c0f53ea29777fdc29afaf7bfad87442488a280662d355fb
# Successfully built plotly
# Installing collected packages: plotly
# Successfully installed plotly-2.5.1
# You are using pip version 9.0.3, however version 10.0.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
#crimes2 = pd.read_csv('F:\Chicago_Crimes_2008_to_2011.csv',error_bad_lines=False)
crimes3 = pd.read_csv('F:\Chicago_Crimes_2012_to_2017.csv',error_bad_lines=False)
#crimes = pd.concat([crimes2, crimes3], ignore_index=False, axis=0)

# %%
crimes3['Primary Type'].isnull().sum()
# Out:
# 0

# %%
crimes.head(3).T
# Out:
#                                                388   \
# Arrest                                         True
# Beat                                            323
# Block                               000XX E 75TH ST
# Case Number                                HP610824
# Community Area                                   69
# Date                         10/07/2008 12:39:00 PM
# Description                     FIRST DEGREE MURDER
# District                                          3
# Domestic                                      False
# FBI Code                                        01A
# ID                                             4785
# IUCR                                           0110
# Latitude                                    41.7583
# Location              (41.758275857, -87.622451031)
# Location Description                          ALLEY
# Longitude                                  -87.6225
# Primary Type                               HOMICIDE
# Unnamed: 0                                      NaN
# Updated On                   08/17/2015 03:03:40 PM
# Ward                                              6
# X Coordinate                            1.17821e+06
# Y Coordinate                            1.85531e+06
# Year                                           2008
#
#                                               835   \
# Arrest                                        True
# Beat                                          1533
# Block                              048XX W POLK ST
# Case Number                               HP616595
# Community Area                                  25
# Date                        10/09/2008 03:30:00 AM
# Description                    FIRST DEGREE MURDER
# District                                        15
# Domestic                                     False
# FBI Code                                       01A
# ID                                            4786
# IUCR                                          0110
# Latitude                                   41.8703
# Location              (41.87025207, -87.746069362)
# Location Description                        STREET
# Longitude                                 -87.7461
# Primary Type                              HOMICIDE
# Unnamed: 0                                     NaN
# Updated On                  08/17/2015 03:03:40 PM
# Ward                                            24
# X Coordinate                            1.1442e+06
# Y Coordinate                           1.89586e+06
# Year                                          2008
#
#                                                1334
# Arrest                                        False
# Beat                                            831
# Block                               030XX W MANN DR
# Case Number                                HP616904
# Community Area                                   66
# Date                         10/09/2008 08:35:00 AM
# Description                     FIRST DEGREE MURDER
# District                                          8
# Domestic                                      False
# FBI Code                                        01A
# ID                                             4787
# IUCR                                           0110
# Latitude                                     41.771
# Location              (41.770990476, -87.698901469)
# Location Description                  PARK PROPERTY
# Longitude                                  -87.6989
# Primary Type                               HOMICIDE
# Unnamed: 0                                      NaN
# Updated On                   08/17/2015 03:03:40 PM
# Ward                                             18
# X Coordinate                            1.15731e+06
# Y Coordinate                            1.85978e+06
# Year                                           2008

# %%
print('Dataset Shape before drop_duplicate : ', crimes.shape)
crimes.drop_duplicates(subset=['ID', 'Case Number'], inplace=True)
print('Dataset Shape after drop_duplicate: ', crimes.shape)
# Out:
# Dataset Shape before drop_duplicate :  (4145424, 23)
# Dataset Shape after drop_duplicate:  (2997929, 23)

# %%
# We Will not be using the following columns for our Exploratory Analysis, Hence we have dropped the coloumns
crimes.drop(['Unnamed: 0', 'Case Number', 'IUCR', 'X Coordinate', 'Y Coordinate','Updated On','Year', 'FBI Code',
             'Beat','Ward','Community Area', 'Location', 'District'], inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-aac1010973d3> in <module>()
#       1 #We Will not be using the following columns for our Exploratory Analysis, Hence we have dropped the coloumns
#       2 crimes.drop(['Unnamed: 0', 'Case Number', 'IUCR', 'X Coordinate', 'Y Coordinate','Updated On','Year', 'FBI Code',
# ----> 3              'Beat','Ward','Community Area', 'Location', 'District'], inplace=True, axis=1)
#
# C:\Users\dell\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# C:\Users\dell\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# C:\Users\dell\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3742             if errors != 'ignore':
#    3743                 raise ValueError('labels %s not contained in axis' %
# -> 3744                                  labels[mask])
#    3745             indexer = indexer[~mask]
#    3746         return self.delete(indexer)
#
# ValueError: labels ['Unnamed: 0' 'Case Number' 'IUCR' 'X Coordinate' 'Y Coordinate'
#  'Updated On' 'Year' 'FBI Code' 'Beat' 'Ward' 'Community Area' 'Location'
#  'District'] not contained in axis

# %%
max_browser = pd.DataFrame(crimes.groupby('Location Description').size().rename('cnt')).idxmax()[0]
crimes['Location Description'] = crimes['Location Description'].fillna(max_browser)
crimes.dropna(subset=['Longitude'], how = 'any', inplace = True)
crimes.dropna(subset=['Latitude'], how = 'any', inplace = True)

# %%
crimes.head(3).T
# Out:
# Date                  2008-10-07 12:39:00  2008-10-09 03:30:00  \
# Arrest                               True                 True
# Block                     000XX E 75TH ST      048XX W POLK ST
# Date                  2008-10-07 12:39:00  2008-10-09 03:30:00
# Description                         OTHER                OTHER
# Domestic                            False                False
# ID                                   4785                 4786
# Latitude                          41.7583              41.8703
# Location Description                ALLEY               STREET
# Longitude                        -87.6225             -87.7461
# Primary Type                     HOMICIDE             HOMICIDE
#
# Date                  2008-10-09 08:35:00
# Arrest                              False
# Block                     030XX W MANN DR
# Date                  2008-10-09 08:35:00
# Description                         OTHER
# Domestic                            False
# ID                                   4787
# Latitude                           41.771
# Location Description        PARK PROPERTY
# Longitude                        -87.6989
# Primary Type                     HOMICIDE

# %%
crimes.isnull().sum()
# Out:
# Arrest                  0
# Block                   0
# Date                    0
# Description             0
# Domestic                0
# ID                      0
# Latitude                0
# Location Description    0
# Longitude               0
# Primary Type            0
# dtype: int64

# %%
crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2997929 entries, 388 to 1456713
# Data columns (total 10 columns):
# Arrest                  bool
# Block                   object
# Date                    object
# Description             object
# Domestic                bool
# ID                      int64
# Latitude                float64
# Location Description    object
# Longitude               float64
# Primary Type            object
# dtypes: bool(2), float64(2), int64(1), object(5)
# memory usage: 211.6+ MB

# %%
#Since date is in object type, we need to convert it to datetime format
crimes3.Date = pd.to_datetime(crimes3.Date, format='%m/%d/%Y %I:%M:%S %p')

# %%
crimes['Primary Type'].isnull().sum()
# Out:
# 0

# %%
## Adding weekday
crimes3['Day']=crimes3['Date'].dt.weekday_name

# %%
## Adding hour
crimes3['Hour']=crimes3['Date'].dt.hour

# %%
## Adding month
crimes3['Month']=crimes3['Date'].dt.month

# %%
## Addning Year
crimes3['Year']= crimes3['Date'].dt.year

# %%
#Setting the index to be date
crimes.index = pd.DatetimeIndex(crimes.Date)

# %%
crimes.shape
# Out:
# (2997929, 10)

# %%
loc_to_change  = list(crimes['Location Description'].value_counts()[20:].index)

# %%
desc_to_change = list(crimes['Description'].value_counts()[20:].index)
crimes.loc[crimes['Location Description'].isin(loc_to_change) , crimes.columns=='Location Description'] = 'OTHER'
crimes.loc[crimes['Description'].isin(desc_to_change) , crimes.columns=='Description'] = 'OTHER'

# %%
crimes['Location Description'] = pd.Categorical(crimes['Location Description'])
crimes['Description']          = pd.Categorical(crimes['Description'])

# %%
plt.figure(figsize=(11,5))
crimes.resample('M').size().plot(legend=False)
plt.title('Number of crimes per month (2008 - 2016)')
plt.xlabel('Months')
plt.ylabel('Number of crimes')
plt.show()

# %%
# Crimes Seperated by types and its occurance in the years
crimes_count_date = crimes.pivot_table('ID', aggfunc=np.size, columns='Primary Type', index=crimes.index.date, fill_value=0)
crimes_count_date.index = pd.DatetimeIndex(crimes_count_date.index)
plo = crimes_count_date.rolling(365).sum().plot(figsize=(12, 30), subplots=True, layout=(-1, 3), sharex=False, sharey=False)

# %%
#Number of crimes during specific days of the week
days = ['Monday','Tuesday','Wednesday',  'Thursday', 'Friday', 'Saturday', 'Sunday']
crimes.groupby([crimes.index.dayofweek]).size().plot(kind='barh')
plt.ylabel('Days of the week')
plt.yticks(np.arange(7), days)
plt.xlabel('Number of crimes')
plt.title('Number of crimes by day of the week')
plt.show()

# %%
#Number of crimes during specific month of the years
crimes.groupby([crimes.index.month]).size().plot(kind='barh')
plt.ylabel('Months of the year')
plt.xlabel('Number of crimes')
plt.title('Number of crimes by month of the year')
plt.show()

# %%
#Number of crimes based on primary type
plt.figure(figsize=(8,10))
crimes.groupby([crimes['Primary Type']]).size().sort_values(ascending=True).plot(kind='barh')
plt.title('Number of crimes by type')
plt.ylabel('Crime Type')
plt.xlabel('Number of crimes')
plt.show()

# %%
x = crimes3.groupby([crimes3['Primary Type']]).size().sort_values(ascending=True)

# %%
c = pd.DataFrame(x)

# %%
c = c.reset_index()

# %%
crimes3['Location Description'].nunique()
# Out:
# 142

# %%
for i,v in c.iterrows():
    print(v['Primary Type'],v[0])
# Out:
# NON-CRIMINAL (SUBJECT SPECIFIED) 4
# HUMAN TRAFFICKING 28
# OTHER NARCOTIC VIOLATION 30
# NON - CRIMINAL 38
# PUBLIC INDECENCY 62
# CONCEALED CARRY LICENSE VIOLATION 90
# NON-CRIMINAL 93
# OBSCENITY 187
# INTIMIDATION 662
# STALKING 828
# KIDNAPPING 1099
# LIQUOR LAW VIOLATION 1953
# GAMBLING 2212
# ARSON 2217
# HOMICIDE 2649
# SEX OFFENSE 4885
# INTERFERENCE WITH PUBLIC OFFICER 6195
# CRIM SEXUAL ASSAULT 6823
# PROSTITUTION 7633
# OFFENSE INVOLVING CHILDREN 11398
# PUBLIC PEACE VIOLATION 13122
# WEAPONS VIOLATION 17233
# CRIMINAL TRESPASS 36912
# ROBBERY 57313
# MOTOR VEHICLE THEFT 61138
# DECEPTIVE PRACTICE 75495
# BURGLARY 83397
# OTHER OFFENSE 87874
# ASSAULT 91289
# NARCOTICS 135240
# CRIMINAL DAMAGE 155455
# BATTERY 263700
# THEFT 329460

# %%
#Based on Location Description
plt.figure(figsize=(8,10))
crimes.groupby([crimes['Location Description']]).size().sort_values(ascending=True).plot(kind='barh')
plt.title('Number of crimes by Location')
plt.ylabel('Crime Location')
plt.xlabel('Number of crimes')
plt.show()

# %%
df['Block area'], df['Street Ad'] , df['Ave'] = df['Block'].str.split('XX' , expand= True).reset_index()
